# %% [markdown]
# **Impor Pustaka yang Diperlukan**

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
import pathlib

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# **Menyiapkan Data dan Melakukan Augmentasi**

# %%
# Menentukan path direktori data lokal
data_dir = pathlib.Path('soil_types')

batch_size = 32
img_height = 180
img_width = 180

# Membuat dataset menggunakan image_dataset_from_directory
train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 156 files belonging to 5 classes.
# Using 125 files for training.
# Found 156 files belonging to 5 classes.
# Using 31 files for validation.

# %%
# Periksa jumlah kelas
class_names = train_ds.class_names
num_classes = len(class_names)
print(f"Number of classes: {num_classes}")
print(f"Class names: {class_names}")
# Out:
# Number of classes: 5
# Class indices: ['black_soil', 'cinder_soil', 'laterite_soil', 'peat_soil', 'yellow_soil']

# %%
# Normalisasi dataset
normalization_layer = tf.keras.layers.Rescaling(1./255)
train_dataset = train_dataset.map(lambda x, y: (normalization_layer(x), y))
validation_dataset = validation_dataset.map(lambda x, y: (normalization_layer(x), y))

# %%
# Prefetch dataset
train_dataset = train_dataset.prefetch(buffer_size=32)
validation_dataset = validation_dataset.prefetch(buffer_size=32)

# %% [markdown]
# **Membangun dan Melatih Model**

# %%
# Membangun model
num_classes = len(class_names)

model = Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()

history = model.fit(
    train_dataset,
    epochs=20,
    validation_data=validation_dataset
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 3,455,173
# Trainable params: 3,455,173
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 4/4 [==============================] - 6s 531ms/step - loss: 1.5992 - accuracy: 0.2400 - val_loss: 1.5330 - val_accuracy: 0.2258
# Epoch 2/20
# 4/4 [==============================] - 0s 65ms/step - loss: 1.3556 - accuracy: 0.3920 - val_loss: 1.0301 - val_accuracy: 0.4516
# Epoch 3/20
# 4/4 [==============================] - 0s 64ms/step - loss: 1.0371 - accuracy: 0.4800 - val_loss: 0.9974 - val_accuracy: 0.3226
# Epoch 4/20
# 4/4 [==============================] - 0s 65ms/step - loss: 0.9407 - accuracy: 0.5360 - val_loss: 0.9765 - val_accuracy: 0.5806
# Epoch 5/20
# 4/4 [==============================] - 0s 63ms/step - loss: 0.9339 - accuracy: 0.5360 - val_loss: 1.5290 - val_accuracy: 0.3871
# Epoch 6/20
# 4/4 [==============================] - 0s 61ms/step - loss: 0.9861 - accuracy: 0.5280 - val_loss: 0.8126 - val_accuracy: 0.5806
# Epoch 7/20
# 4/4 [==============================] - 0s 63ms/step - loss: 0.7862 - accuracy: 0.5920 - val_loss: 0.9402 - val_accuracy: 0.5806
# Epoch 8/20
# 4/4 [==============================] - 0s 57ms/step - loss: 0.7436 - accuracy: 0.7280 - val_loss: 0.7337 - val_accuracy: 0.7097
# Epoch 9/20
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6820 - accuracy: 0.6720 - val_loss: 1.1894 - val_accuracy: 0.5484
# Epoch 10/20
# 4/4 [==============================] - 0s 68ms/step - loss: 0.5676 - accuracy: 0.8000 - val_loss: 0.6891 - val_accuracy: 0.6774
# Epoch 11/20
# 4/4 [==============================] - 0s 58ms/step - loss: 0.4617 - accuracy: 0.8080 - val_loss: 0.7091 - val_accuracy: 0.7419
# Epoch 12/20
# 4/4 [==============================] - 0s 64ms/step - loss: 0.4231 - accuracy: 0.8560 - val_loss: 0.9287 - val_accuracy: 0.5806
# Epoch 13/20
# 4/4 [==============================] - 0s 63ms/step - loss: 0.5463 - accuracy: 0.7760 - val_loss: 0.6717 - val_accuracy: 0.7097
# Epoch 14/20
# 4/4 [==============================] - 0s 60ms/step - loss: 0.5061 - accuracy: 0.8080 - val_loss: 0.9251 - val_accuracy: 0.6774
# Epoch 15/20
# 4/4 [==============================] - 0s 60ms/step - loss: 0.4491 - accuracy: 0.8080 - val_loss: 0.6022 - val_accuracy: 0.7742
# Epoch 16/20
# 4/4 [==============================] - 0s 64ms/step - loss: 0.3598 - accuracy: 0.8480 - val_loss: 0.7198 - val_accuracy: 0.7097
# Epoch 17/20
# 4/4 [==============================] - 0s 62ms/step - loss: 0.2614 - accuracy: 0.9120 - val_loss: 0.5539 - val_accuracy: 0.7742
# Epoch 18/20
# 4/4 [==============================] - 0s 65ms/step - loss: 0.2804 - accuracy: 0.9200 - val_loss: 0.7261 - val_accuracy: 0.7097
# Epoch 19/20
# 4/4 [==============================] - 0s 60ms/step - loss: 0.2500 - accuracy: 0.9200 - val_loss: 0.4792 - val_accuracy: 0.8387
# Epoch 20/20
# 4/4 [==============================] - 0s 66ms/step - loss: 0.2086 - accuracy: 0.9440 - val_loss: 0.8342 - val_accuracy: 0.6774

# %%
# Ekstrak history dari training
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

# Plot akurasi training dan validasi
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

# Plot loss training dan validasi
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
model = Sequential([
    data_augmentation,
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(num_classes, name="outputs")
])


model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()

history = model.fit(
    train_dataset,
    epochs=25,
    validation_data=validation_dataset
)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 150, 150, 3)       0
#
#  conv2d_8 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_8 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_9 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 34, 34, 128)       73856
#
#  max_pooling2d_10 (MaxPoolin  (None, 17, 17, 128)      0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 15, 15, 128)       147584
#
#  max_pooling2d_11 (MaxPoolin  (None, 7, 7, 128)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 128)         0
#
#  flatten_2 (Flatten)         (None, 6272)              0
#
#  dense_3 (Dense)             (None, 512)               3211776
#
#  outputs (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 3,455,173
# Trainable params: 3,455,173
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 4/4 [==============================] - 4s 341ms/step - loss: 1.7210 - accuracy: 0.2000 - val_loss: 1.5618 - val_accuracy: 0.4516
# Epoch 2/25
# 4/4 [==============================] - 1s 311ms/step - loss: 1.5164 - accuracy: 0.3520 - val_loss: 1.2521 - val_accuracy: 0.4194
# Epoch 3/25
# 4/4 [==============================] - 1s 328ms/step - loss: 1.1748 - accuracy: 0.3600 - val_loss: 1.1157 - val_accuracy: 0.4194
# Epoch 4/25
# 4/4 [==============================] - 1s 328ms/step - loss: 1.0545 - accuracy: 0.4640 - val_loss: 1.2168 - val_accuracy: 0.4839
# Epoch 5/25
# 4/4 [==============================] - 1s 333ms/step - loss: 1.0147 - accuracy: 0.4480 - val_loss: 1.5009 - val_accuracy: 0.4194
# Epoch 6/25
# 4/4 [==============================] - 1s 328ms/step - loss: 0.9944 - accuracy: 0.5280 - val_loss: 0.9511 - val_accuracy: 0.4839
# Epoch 7/25
# 4/4 [==============================] - 1s 327ms/step - loss: 0.9436 - accuracy: 0.4640 - val_loss: 0.8895 - val_accuracy: 0.5806
# Epoch 8/25
# 4/4 [==============================] - 1s 334ms/step - loss: 0.8478 - accuracy: 0.6160 - val_loss: 1.0372 - val_accuracy: 0.4516
# Epoch 9/25
# 4/4 [==============================] - 1s 336ms/step - loss: 0.7966 - accuracy: 0.7360 - val_loss: 0.8841 - val_accuracy: 0.5484
# Epoch 10/25
# 4/4 [==============================] - 1s 345ms/step - loss: 0.7248 - accuracy: 0.6800 - val_loss: 0.8897 - val_accuracy: 0.5484
# Epoch 11/25
# 4/4 [==============================] - 1s 333ms/step - loss: 0.6764 - accuracy: 0.7520 - val_loss: 0.9198 - val_accuracy: 0.5806
# Epoch 12/25
# 4/4 [==============================] - 1s 328ms/step - loss: 0.6315 - accuracy: 0.7280 - val_loss: 1.2238 - val_accuracy: 0.5484
# Epoch 13/25
# 4/4 [==============================] - 1s 332ms/step - loss: 0.5190 - accuracy: 0.7760 - val_loss: 0.8802 - val_accuracy: 0.7097
# Epoch 14/25
# 4/4 [==============================] - 1s 326ms/step - loss: 0.5369 - accuracy: 0.7680 - val_loss: 0.9181 - val_accuracy: 0.6774
# Epoch 15/25
# 4/4 [==============================] - 1s 334ms/step - loss: 0.4846 - accuracy: 0.8160 - val_loss: 0.8866 - val_accuracy: 0.7419
# Epoch 16/25
# 4/4 [==============================] - 1s 340ms/step - loss: 0.4492 - accuracy: 0.8400 - val_loss: 0.8228 - val_accuracy: 0.6774
# Epoch 17/25
# 4/4 [==============================] - 1s 329ms/step - loss: 0.6230 - accuracy: 0.7040 - val_loss: 1.3310 - val_accuracy: 0.6129
# Epoch 18/25
# 4/4 [==============================] - 1s 333ms/step - loss: 0.5668 - accuracy: 0.7920 - val_loss: 1.0202 - val_accuracy: 0.6774
# Epoch 19/25
# 4/4 [==============================] - 1s 331ms/step - loss: 0.4955 - accuracy: 0.8000 - val_loss: 1.0529 - val_accuracy: 0.6774
# Epoch 20/25
# 4/4 [==============================] - 1s 328ms/step - loss: 0.5279 - accuracy: 0.7760 - val_loss: 0.8563 - val_accuracy: 0.7419
# Epoch 21/25
# 4/4 [==============================] - 1s 331ms/step - loss: 0.4406 - accuracy: 0.8320 - val_loss: 1.0635 - val_accuracy: 0.5484
# Epoch 22/25
# 4/4 [==============================] - 1s 332ms/step - loss: 0.5292 - accuracy: 0.7360 - val_loss: 0.7261 - val_accuracy: 0.7097
# Epoch 23/25
# 4/4 [==============================] - 1s 348ms/step - loss: 0.4748 - accuracy: 0.8000 - val_loss: 1.0258 - val_accuracy: 0.7097
# Epoch 24/25
# 4/4 [==============================] - 1s 335ms/step - loss: 0.4107 - accuracy: 0.8320 - val_loss: 0.8765 - val_accuracy: 0.7097
# Epoch 25/25
# 4/4 [==============================] - 1s 328ms/step - loss: 0.3800 - accuracy: 0.8640 - val_loss: 1.1278 - val_accuracy: 0.7097

# %%
# Ekstrak history dari training
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

# Plot akurasi training dan validasi
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

# Plot loss training dan validasi
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()

# %%
img_path = 'black_soil_ex.jpg'

img = tf.keras.utils.load_img(
    img_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 402ms/step
# This image most likely belongs to cinder_soil with a 100.00 percent confidence.

# %% [markdown]
# **Menyimpan Model yang Telah Dilatih**

# %%
model.save('soil_type_classifier.h5')

# %% [markdown]
# **Memuat Model yang Telah Disimpan dan Melakukan Prediksi pada Gambar Baru**

# %%
# Mendapatkan nama kelas dari generator
class_indices = train_generator.class_names
# Membalikkan dictionary untuk mendapatkan nama kelas dari indeks
class_names = {v: k for k, v in class_indices.items()}

def predict_image(image_path):
    # Memuat dan memproses gambar
    img = image.load_img(image_path, target_size=(img_height, img_width))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0  # Normalisasi gambar

    # Membuat prediksi
    predictions = model.predict(img_array)
    predicted_class_idx = np.argmax(predictions)
    predicted_class = class_names[predicted_class_idx]
    predicted_proba = np.max(predictions)

    return predicted_class, predicted_proba

# Contoh penggunaan: prediksi gambar yang dikirimkan oleh pengguna
user_image_path = 'black_soil_ex.jpg'
predicted_class, predicted_proba = predict_image(user_image_path)
print(f"Predicted class: {predicted_class}")
print(f"Prediction confidence: {predicted_proba * 100:.2f}%")
